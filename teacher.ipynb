# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# gradient descent method
def funct(x1, x2):
  result = (x1**2+x2**2-3)**2+ (x1**2-x2**2)**2
  return result

# %%
def grad(x1, x2):
  #result = np.array([4*(x1**2+x2**2-3)*x1+4*(x1**2-x2**2)*x1, 4*(x1**2+x2**2-3)*x2+4*(x1**2-x2**2)*x2])
  funct_val = funct(x1, x2)
  h = 1e-9
  result = np.array([(funct(x1+h, x2)- funct_val)/h, (funct(x1, x2+h)- funct_val)/h])

  return result

# %%
x = -1*np.ones((1,2))
x[0,1] = 1
print(x)
step = 0.1
funct_old = funct(x[0,0],x[0,1])
gradient = grad(x[0,0],x[0,1])
direction = gradient/np.linalg.norm(gradient)
iterationsInSameDirection = 0
functionValues = [funct_old]
for i in range(1000):
  
  
  x = x - step*direction
  funct_new = funct(x[0,0],x[0,1])
  iterationsInSameDirection += 1
  print("Iteration {:5d},f(x) {:7.6e}".format(i,np.abs(funct(x[0,0],x[0,1]))))
  if funct_new > funct_old:
    x = x + step*direction
    step = step /1.05
    gradient = grad(x[0,0],x[0,1])
    direction = gradient/np.linalg.norm(gradient)
    iterationsInSameDirection = 0
    print("Gradient recalculated condition 1: function increases")
  elif ((iterationsInSameDirection+1)%50) == 0:
    gradient = grad(x[0,0],x[0,1])
    direction = gradient/np.linalg.norm(gradient) 
    iterationsInSameDirection = 0
    print("Gradient recalculated condition 2: number of iterations")    
  else:
   funct_old =   funct_new
  functionValues.append(funct_new)  
  if abs(funct_new)< 1e-9:
    break

plt.plot(functionValues)
plt.xlabel('Iteration')
plt.ylabel('Function value')
print(x)
print(np.abs(funct(x[0,0],x[0,1])))

plt.show()
# Out:
# [[-1.  1.]]
# Iteration     0,f(x) 5.000714e-01
# Iteration     1,f(x) 1.554840e-01
# Iteration     2,f(x) 3.778790e-03
# Iteration     3,f(x) 8.489697e-02
# Gradient recalculated condition 1: function increases
# Iteration     4,f(x) 7.513920e-02
# Gradient recalculated condition 1: function increases
# Iteration     5,f(x) 6.642146e-02
# Gradient recalculated condition 1: function increases
# Iteration     6,f(x) 5.863697e-02
# Gradient recalculated condition 1: function increases
# Iteration     7,f(x) 5.168988e-02
# Gradient recalculated condition 1: function increases
# Iteration     8,f(x) 4.549412e-02
# Gradient recalculated condition 1: function increases
# Iteration     9,f(x) 3.997241e-02
# Gradient recalculated condition 1: function increases
# Iteration    10,f(x) 3.505535e-02
# Gradient recalculated condition 1: function increases
# Iteration    11,f(x) 3.068057e-02
# Gradient recalculated condition 1: function increases
# Iteration    12,f(x) 2.679206e-02
# Gradient recalculated condition 1: function increases
# Iteration    13,f(x) 2.333950e-02
# Gradient recalculated condition 1: function increases
# Iteration    14,f(x) 2.027767e-02
# Gradient recalculated condition 1: function increases
# Iteration    15,f(x) 1.756592e-02
# Gradient recalculated condition 1: function increases
# Iteration    16,f(x) 1.516773e-02
# Gradient recalculated condition 1: function increases
# Iteration    17,f(x) 1.305031e-02
# Gradient recalculated condition 1: function increases
# Iteration    18,f(x) 1.118415e-02
# Gradient recalculated condition 1: function increases
# Iteration    19,f(x) 9.542749e-03
# Gradient recalculated condition 1: function increases
# Iteration    20,f(x) 8.102309e-03
# Gradient recalculated condition 1: function increases
# Iteration    21,f(x) 6.841430e-03
# Gradient recalculated condition 1: function increases
# Iteration    22,f(x) 5.740895e-03
# Gradient recalculated condition 1: function increases
# Iteration    23,f(x) 4.783439e-03
# Gradient recalculated condition 1: function increases
# Iteration    24,f(x) 3.953556e-03
# Gradient recalculated condition 1: function increases
# Iteration    25,f(x) 3.237324e-03
# Iteration    26,f(x) 3.154320e-02
# Gradient recalculated condition 1: function increases
# Iteration    27,f(x) 3.123494e-03
# Iteration    28,f(x) 2.774024e-02
# Gradient recalculated condition 1: function increases
# Iteration    29,f(x) 2.650053e-03
# Iteration    30,f(x) 2.584648e-02
# Gradient recalculated condition 1: function increases
# Iteration    31,f(x) 2.582583e-03
# Iteration    32,f(x) 2.291373e-02
# Gradient recalculated condition 1: function increases
# Iteration    33,f(x) 2.168560e-03
# Iteration    34,f(x) 2.118091e-02
# Gradient recalculated condition 1: function increases
# Iteration    35,f(x) 2.136059e-03
# Iteration    36,f(x) 1.892495e-02
# Gradient recalculated condition 1: function increases
# Iteration    37,f(x) 1.773834e-03
# Iteration    38,f(x) 1.735880e-02
# Gradient recalculated condition 1: function increases
# Iteration    39,f(x) 1.767414e-03
# Iteration    40,f(x) 1.562943e-02
# Gradient recalculated condition 1: function increases
# Iteration    41,f(x) 1.450288e-03
# Iteration    42,f(x) 1.422691e-02
# Gradient recalculated condition 1: function increases
# Iteration    43,f(x) 1.463025e-03
# Gradient recalculated condition 1: function increases
# Iteration    44,f(x) 1.199699e-03
# Iteration    45,f(x) 1.133695e-02
# Gradient recalculated condition 1: function increases
# Iteration    46,f(x) 1.197149e-03
# Iteration    47,f(x) 1.094855e-02
# Gradient recalculated condition 1: function increases
# Iteration    48,f(x) 9.833123e-04
# Iteration    49,f(x) 9.329776e-03
# Gradient recalculated condition 1: function increases
# Iteration    50,f(x) 9.886352e-04
# Gradient recalculated condition 1: function increases
# Iteration    51,f(x) 8.086727e-04
# Iteration    52,f(x) 7.890478e-03
# Gradient recalculated condition 1: function increases
# Iteration    53,f(x) 8.136157e-04
# Gradient recalculated condition 1: function increases
# Iteration    54,f(x) 6.668675e-04
# Iteration    55,f(x) 6.335240e-03
# Gradient recalculated condition 1: function increases
# Iteration    56,f(x) 6.678190e-04
# Gradient recalculated condition 1: function increases
# Iteration    57,f(x) 5.462420e-04
# Iteration    58,f(x) 5.324761e-03
# Gradient recalculated condition 1: function increases
# Iteration    59,f(x) 5.517933e-04
# Gradient recalculated condition 1: function increases
# Iteration    60,f(x) 4.522875e-04
# Iteration    61,f(x) 4.299941e-03
# Gradient recalculated condition 1: function increases
# Iteration    62,f(x) 4.510795e-04
# Iteration    63,f(x) 4.101819e-03
# Gradient recalculated condition 1: function increases
# Iteration    64,f(x) 3.705548e-04
# Iteration    65,f(x) 3.536098e-03
# Gradient recalculated condition 1: function increases
# Iteration    66,f(x) 3.726605e-04
# Gradient recalculated condition 1: function increases
# Iteration    67,f(x) 3.049523e-04
# Iteration    68,f(x) 2.959390e-03
# Gradient recalculated condition 1: function increases
# Iteration    69,f(x) 3.064836e-04
# Gradient recalculated condition 1: function increases
# Iteration    70,f(x) 2.510982e-04
# Iteration    71,f(x) 2.398078e-03
# Gradient recalculated condition 1: function increases
# Iteration    72,f(x) 2.519379e-04
# Gradient recalculated condition 1: function increases
# Iteration    73,f(x) 2.061619e-04
# Iteration    74,f(x) 1.999417e-03
# Gradient recalculated condition 1: function increases
# Iteration    75,f(x) 2.076833e-04
# Gradient recalculated condition 1: function increases
# Iteration    76,f(x) 1.701556e-04
# Iteration    77,f(x) 1.625860e-03
# Gradient recalculated condition 1: function increases
# Iteration    78,f(x) 1.703184e-04
# Gradient recalculated condition 1: function increases
# Iteration    79,f(x) 1.393679e-04
# Iteration    80,f(x) 1.351161e-03
# Gradient recalculated condition 1: function increases
# Iteration    81,f(x) 1.407398e-04
# Gradient recalculated condition 1: function increases
# Iteration    82,f(x) 1.153135e-04
# Iteration    83,f(x) 1.102078e-03
# Gradient recalculated condition 1: function increases
# Iteration    84,f(x) 1.151325e-04
# Iteration    85,f(x) 1.041688e-03
# Gradient recalculated condition 1: function increases
# Iteration    86,f(x) 9.443660e-05
# Iteration    87,f(x) 9.057697e-04
# Gradient recalculated condition 1: function increases
# Iteration    88,f(x) 9.515410e-05
# Gradient recalculated condition 1: function increases
# Iteration    89,f(x) 7.789826e-05
# Iteration    90,f(x) 7.522496e-04
# Gradient recalculated condition 1: function increases
# Iteration    91,f(x) 7.807682e-05
# Gradient recalculated condition 1: function increases
# Iteration    92,f(x) 6.393978e-05
# Iteration    93,f(x) 6.136179e-04
# Gradient recalculated condition 1: function increases
# Iteration    94,f(x) 6.438251e-05
# Gradient recalculated condition 1: function increases
# Iteration    95,f(x) 5.270817e-05
# Iteration    96,f(x) 5.087330e-04
# Gradient recalculated condition 1: function increases
# Iteration    97,f(x) 5.286200e-05
# Gradient recalculated condition 1: function increases
# Iteration    98,f(x) 4.328965e-05
# Iteration    99,f(x) 4.156336e-04
# Gradient recalculated condition 1: function increases
# Iteration   100,f(x) 4.356383e-05
# Gradient recalculated condition 1: function increases
# Iteration   101,f(x) 3.566509e-05
# Iteration   102,f(x) 3.440950e-04
# Gradient recalculated condition 1: function increases
# Iteration   103,f(x) 3.578901e-05
# Gradient recalculated condition 1: function increases
# Iteration   104,f(x) 2.930786e-05
# Iteration   105,f(x) 2.814935e-04
# Gradient recalculated condition 1: function increases
# Iteration   106,f(x) 2.947794e-05
# Gradient recalculated condition 1: function increases
# Iteration   107,f(x) 2.413344e-05
# Iteration   108,f(x) 2.327641e-04
# Gradient recalculated condition 1: function increases
# Iteration   109,f(x) 2.422953e-05
# Gradient recalculated condition 1: function increases
# Iteration   110,f(x) 1.984155e-05
# Iteration   111,f(x) 1.906258e-04
# Gradient recalculated condition 1: function increases
# Iteration   112,f(x) 1.994696e-05
# Gradient recalculated condition 1: function increases
# Iteration   113,f(x) 1.633058e-05
# Iteration   114,f(x) 1.574683e-04
# Gradient recalculated condition 1: function increases
# Iteration   115,f(x) 1.640340e-05
# Gradient recalculated condition 1: function increases
# Iteration   116,f(x) 1.343268e-05
# Iteration   117,f(x) 1.290800e-04
# Gradient recalculated condition 1: function increases
# Iteration   118,f(x) 1.349774e-05
# Gradient recalculated condition 1: function increases
# Iteration   119,f(x) 1.105062e-05
# Iteration   120,f(x) 1.065375e-04
# Gradient recalculated condition 1: function increases
# Iteration   121,f(x) 1.110504e-05
# Gradient recalculated condition 1: function increases
# Iteration   122,f(x) 9.093878e-06
# Iteration   123,f(x) 8.739932e-05
# Gradient recalculated condition 1: function increases
# Iteration   124,f(x) 9.133680e-06
# Gradient recalculated condition 1: function increases
# Iteration   125,f(x) 7.477740e-06
# Iteration   126,f(x) 7.208363e-05
# Gradient recalculated condition 1: function increases
# Iteration   127,f(x) 7.518092e-06
# Gradient recalculated condition 1: function increases
# Iteration   128,f(x) 6.156570e-06
# Iteration   129,f(x) 5.917454e-05
# Gradient recalculated condition 1: function increases
# Iteration   130,f(x) 6.180553e-06
# Gradient recalculated condition 1: function increases
# Iteration   131,f(x) 5.059979e-06
# Iteration   132,f(x) 4.877421e-05
# Gradient recalculated condition 1: function increases
# Iteration   133,f(x) 5.089795e-06
# Gradient recalculated condition 1: function increases
# Iteration   134,f(x) 4.168076e-06
# Iteration   135,f(x) 4.006313e-05
# Gradient recalculated condition 1: function increases
# Iteration   136,f(x) 4.182171e-06
# Gradient recalculated condition 1: function increases
# Iteration   137,f(x) 3.423875e-06
# Iteration   138,f(x) 3.300335e-05
# Gradient recalculated condition 1: function increases
# Iteration   139,f(x) 3.445897e-06
# Gradient recalculated condition 1: function increases
# Iteration   140,f(x) 2.821915e-06
# Iteration   141,f(x) 2.712333e-05
# Gradient recalculated condition 1: function increases
# Iteration   142,f(x) 2.829858e-06
# Gradient recalculated condition 1: function increases
# Iteration   143,f(x) 2.316718e-06
# Iteration   144,f(x) 2.233241e-05
# Gradient recalculated condition 1: function increases
# Iteration   145,f(x) 2.333017e-06
# Gradient recalculated condition 1: function increases
# Iteration   146,f(x) 1.910594e-06
# Iteration   147,f(x) 1.836256e-05
# Gradient recalculated condition 1: function increases
# Iteration   148,f(x) 1.914747e-06
# Gradient recalculated condition 1: function increases
# Iteration   149,f(x) 1.567508e-06
# Iteration   150,f(x) 1.511189e-05
# Gradient recalculated condition 1: function increases
# Iteration   151,f(x) 1.579618e-06
# Gradient recalculated condition 1: function increases
# Iteration   152,f(x) 1.293643e-06
# Iteration   153,f(x) 1.243140e-05
# Gradient recalculated condition 1: function increases
# Iteration   154,f(x) 1.295498e-06
# Gradient recalculated condition 1: function increases
# Iteration   155,f(x) 1.060527e-06
# Iteration   156,f(x) 1.022596e-05
# Gradient recalculated condition 1: function increases
# Iteration   157,f(x) 1.069573e-06
# Gradient recalculated condition 1: function increases
# Iteration   158,f(x) 8.759673e-07
# Iteration   159,f(x) 8.416018e-06
# Gradient recalculated condition 1: function increases
# Iteration   160,f(x) 8.764651e-07
# Gradient recalculated condition 1: function increases
# Iteration   161,f(x) 7.174682e-07
# Iteration   162,f(x) 6.919693e-06
# Gradient recalculated condition 1: function increases
# Iteration   163,f(x) 7.242692e-07
# Gradient recalculated condition 1: function increases
# Iteration   164,f(x) 5.931931e-07
# Iteration   165,f(x) 5.697672e-06
# Gradient recalculated condition 1: function increases
# Iteration   166,f(x) 5.929221e-07
# Iteration   167,f(x) 5.338938e-06
# Gradient recalculated condition 1: function increases
# Iteration   168,f(x) 4.856085e-07
# Iteration   169,f(x) 4.680161e-06
# Gradient recalculated condition 1: function increases
# Iteration   170,f(x) 4.902173e-07
# Gradient recalculated condition 1: function increases
# Iteration   171,f(x) 4.014787e-07
# Iteration   172,f(x) 3.858860e-06
# Gradient recalculated condition 1: function increases
# Iteration   173,f(x) 4.013307e-07
# Iteration   174,f(x) 3.611403e-06
# Gradient recalculated condition 1: function increases
# Iteration   175,f(x) 3.286475e-07
# Iteration   176,f(x) 3.169487e-06
# Gradient recalculated condition 1: function increases
# Iteration   177,f(x) 3.318293e-07
# Gradient recalculated condition 1: function increases
# Iteration   178,f(x) 2.717761e-07
# Iteration   179,f(x) 2.610555e-06
# Gradient recalculated condition 1: function increases
# Iteration   180,f(x) 2.715969e-07
# Iteration   181,f(x) 2.445476e-06
# Gradient recalculated condition 1: function increases
# Iteration   182,f(x) 2.224859e-07
# Iteration   183,f(x) 2.144331e-06
# Gradient recalculated condition 1: function increases
# Iteration   184,f(x) 2.245509e-07
# Gradient recalculated condition 1: function increases
# Iteration   185,f(x) 1.839024e-07
# Iteration   186,f(x) 1.767560e-06
# Gradient recalculated condition 1: function increases
# Iteration   187,f(x) 1.838739e-07
# Iteration   188,f(x) 1.654635e-06
# Gradient recalculated condition 1: function increases
# Iteration   189,f(x) 1.505405e-07
# Iteration   190,f(x) 1.451801e-06
# Gradient recalculated condition 1: function increases
# Iteration   191,f(x) 1.520317e-07
# Gradient recalculated condition 1: function increases
# Iteration   192,f(x) 1.245183e-07
# Iteration   193,f(x) 1.196064e-06
# Gradient recalculated condition 1: function increases
# Iteration   194,f(x) 1.244072e-07
# Iteration   195,f(x) 1.120173e-06
# Gradient recalculated condition 1: function increases
# Iteration   196,f(x) 1.019359e-07
# Iteration   197,f(x) 9.824514e-07
# Gradient recalculated condition 1: function increases
# Iteration   198,f(x) 1.028567e-07
# Gradient recalculated condition 1: function increases
# Iteration   199,f(x) 8.423678e-08
# Iteration   200,f(x) 8.096534e-07
# Gradient recalculated condition 1: function increases
# Iteration   201,f(x) 8.424576e-08
# Gradient recalculated condition 1: function increases
# Iteration   202,f(x) 6.896414e-08
# Iteration   203,f(x) 6.648857e-07
# Gradient recalculated condition 1: function increases
# Iteration   204,f(x) 6.964774e-08
# Gradient recalculated condition 1: function increases
# Iteration   205,f(x) 5.704225e-08
# Iteration   206,f(x) 5.480775e-07
# Gradient recalculated condition 1: function increases
# Iteration   207,f(x) 5.699337e-08
# Iteration   208,f(x) 5.130325e-07
# Gradient recalculated condition 1: function increases
# Iteration   209,f(x) 4.669619e-08
# Iteration   210,f(x) 4.501784e-07
# Gradient recalculated condition 1: function increases
# Iteration   211,f(x) 4.712166e-08
# Gradient recalculated condition 1: function increases
# Iteration   212,f(x) 3.859217e-08
# Iteration   213,f(x) 3.708352e-07
# Gradient recalculated condition 1: function increases
# Iteration   214,f(x) 3.859162e-08
# Iteration   215,f(x) 3.473566e-07
# Gradient recalculated condition 1: function increases
# Iteration   216,f(x) 3.159155e-08
# Iteration   217,f(x) 3.045985e-07
# Gradient recalculated condition 1: function increases
# Iteration   218,f(x) 3.190815e-08
# Gradient recalculated condition 1: function increases
# Iteration   219,f(x) 2.613334e-08
# Iteration   220,f(x) 2.510767e-07
# Gradient recalculated condition 1: function increases
# Iteration   221,f(x) 2.610769e-08
# Iteration   222,f(x) 2.350293e-07
# Gradient recalculated condition 1: function increases
# Iteration   223,f(x) 2.139359e-08
# Iteration   224,f(x) 2.062300e-07
# Gradient recalculated condition 1: function increases
# Iteration   225,f(x) 2.158544e-08
# Gradient recalculated condition 1: function increases
# Iteration   226,f(x) 1.767809e-08
# Iteration   227,f(x) 1.698845e-07
# Gradient recalculated condition 1: function increases
# Iteration   228,f(x) 1.768070e-08
# Gradient recalculated condition 1: function increases
# Iteration   229,f(x) 1.447336e-08
# Iteration   230,f(x) 1.395622e-07
# Gradient recalculated condition 1: function increases
# Iteration   231,f(x) 1.461657e-08
# Gradient recalculated condition 1: function increases
# Iteration   232,f(x) 1.197127e-08
# Iteration   233,f(x) 1.150045e-07
# Gradient recalculated condition 1: function increases
# Iteration   234,f(x) 1.196095e-08
# Iteration   235,f(x) 1.076847e-07
# Gradient recalculated condition 1: function increases
# Iteration   236,f(x) 9.800093e-09
# Iteration   237,f(x) 9.446385e-08
# Gradient recalculated condition 1: function increases
# Iteration   238,f(x) 9.889103e-09
# Gradient recalculated condition 1: function increases
# Iteration   239,f(x) 8.098978e-09
# Iteration   240,f(x) 7.783543e-08
# Gradient recalculated condition 1: function increases
# Iteration   241,f(x) 8.099288e-09
# Gradient recalculated condition 1: function increases
# Iteration   242,f(x) 6.630063e-09
# Iteration   243,f(x) 6.392798e-08
# Gradient recalculated condition 1: function increases
# Iteration   244,f(x) 6.696375e-09
# Gradient recalculated condition 1: function increases
# Iteration   245,f(x) 5.484462e-09
# Iteration   246,f(x) 5.269024e-08
# Gradient recalculated condition 1: function increases
# Iteration   247,f(x) 5.479163e-09
# Iteration   248,f(x) 4.932674e-08
# Gradient recalculated condition 1: function increases
# Iteration   249,f(x) 4.489766e-09
# Iteration   250,f(x) 4.327902e-08
# Gradient recalculated condition 1: function increases
# Iteration   251,f(x) 4.530080e-09
# Gradient recalculated condition 1: function increases
# Iteration   252,f(x) 3.710046e-09
# Iteration   253,f(x) 3.565423e-08
# Gradient recalculated condition 1: function increases
# Iteration   254,f(x) 3.710567e-09
# Gradient recalculated condition 1: function increases
# Iteration   255,f(x) 3.037464e-09
# Iteration   256,f(x) 2.928848e-08
# Gradient recalculated condition 1: function increases
# Iteration   257,f(x) 3.067529e-09
# Gradient recalculated condition 1: function increases
# Iteration   258,f(x) 2.512364e-09
# Iteration   259,f(x) 2.413621e-08
# Gradient recalculated condition 1: function increases
# Iteration   260,f(x) 2.510199e-09
# Iteration   261,f(x) 2.259879e-08
# Gradient recalculated condition 1: function increases
# Iteration   262,f(x) 2.056703e-09
# Iteration   263,f(x) 1.982524e-08
# Gradient recalculated condition 1: function increases
# Iteration   264,f(x) 2.075393e-09
# Gradient recalculated condition 1: function increases
# Iteration   265,f(x) 1.699709e-09
# Iteration   266,f(x) 1.633468e-08
# Gradient recalculated condition 1: function increases
# Iteration   267,f(x) 1.699759e-09
# Gradient recalculated condition 1: function increases
# Iteration   268,f(x) 1.391417e-09
# Iteration   269,f(x) 1.341657e-08
# Gradient recalculated condition 1: function increases
# Iteration   270,f(x) 1.405351e-09
# Gradient recalculated condition 1: function increases
# Iteration   271,f(x) 1.151013e-09
# Iteration   272,f(x) 1.105772e-08
# Gradient recalculated condition 1: function increases
# Iteration   273,f(x) 1.149881e-09
# Iteration   274,f(x) 1.035217e-08
# Gradient recalculated condition 1: function increases
# Iteration   275,f(x) 9.422599e-10
# [[-1.22475114  1.22475114]]
# 9.422599025508157e-10
